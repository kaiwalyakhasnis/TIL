# %% [markdown]
# Install numpy and torch using
# %pip install numpy
# %pip install torch

# %%
import numpy as np
import torch

# %% [markdown]
# #### Tensor creation using numpy

# %%
arr = np.arange(1, 5)

# %%
tensor_1 = torch.tensor(arr)

# %%
tensor_1
# Out:
# tensor([1, 2, 3, 4])

# %%
tensor_2 = torch.from_numpy(arr)

# %%
tensor_2
# Out:
# tensor([1., 2., 3., 4.])

# %% [markdown]
# #### torch.tensor(arr) Vs torch.from_numpy(arr)

# %%
arr[0] = 999

# %%
tensor_1
# Out:
# tensor([1, 2, 3, 4])

# %%
tensor_2
# Out:
# tensor([999,   2,   3,   4])

# %%
#### tensor creation without numPy

# %%
torch.empty(2)
# Out:
# tensor([6.6310e-07, 1.0314e-08])

# %%
tensor_onces = torch.ones(2,2)

# %%
tensor_onces.dtype
# Out:
# torch.float32
